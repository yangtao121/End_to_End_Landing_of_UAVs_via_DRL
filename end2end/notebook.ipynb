# %%
from PPO.Model import Model1, V_Model
import cv2
from matplotlib import pyplot as plt
import numpy as np
import tensorflow as tf
import time

# %%
# actor = Model1(64, 64)
img = cv2.imread("3.jpg")

img = cv2.resize(img, (64,64))

img = np.array(img)

gray_img = img[:,:,0]

plt.imshow(gray_img,cmap="gray")

# %% [markdown]
# # training before

# %%
actor = Model1(64, 64)

gray_img = np.reshape(gray_img,(1,64,64,1))
gray_img = tf.cast(gray_img, dtype=tf.float32)
actor(gray_img)
# Out:
# <tf.Tensor: shape=(1, 3), dtype=float32, numpy=array([[-0.44723353, -0.5019099 , -0.48612332]], dtype=float32)>

# %%
actor.load_weights("./trier3/policy.h5")
actor(gray_img)
# Out:
# <tf.Tensor: shape=(1, 3), dtype=float32, numpy=array([[-0.94964516, -0.94310635, -0.98630893]], dtype=float32)>

# %%
actor.load_weights('./trier3/model/stage0/0/policy.h5')
actor(gray_img)
# Out:
# <tf.Tensor: shape=(1, 3), dtype=float32, numpy=array([[ 0.750947 ,  0.9163539, -0.9866109]], dtype=float32)>

# %%
actor.load_weights('./trier6/policy.h5')
actor(gray_img)
# Out:
# <tf.Tensor: shape=(1, 3), dtype=float32, numpy=array([[-0.9826095 , -0.31237537, -0.9855563 ]], dtype=float32)>

# %%
start = time.time()

for i in range(100):
    actor(gray_img)

end = time.time()

print((end - start)/100)
# Out:
# 0.0012541818618774414
